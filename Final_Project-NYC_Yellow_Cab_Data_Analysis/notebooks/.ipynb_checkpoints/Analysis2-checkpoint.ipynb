# %% [markdown]
# ## Question  2
# ### Average Credit Vs Cash Payments Per Borough

# %%
import pandas as pd
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
extracted_files = glob.glob('..\\Data\\*\\*\\processed\\*.csv')
df = pd.DataFrame()
list_ = []
for fileName in extracted_files:
    short_df = pd.read_csv(fileName)
    list_.append(short_df)
df = pd.concat(list_)

# %%
df.head()
# Out:
#    index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      0         1  2016-01-01 00:00:01   2016-01-01 00:11:55
# 1      1         1  2016-01-01 00:00:02   2016-01-01 00:11:14
# 2      2         1  2016-01-01 00:00:04   2016-01-01 00:14:32
# 3      3         1  2016-01-01 00:00:05   2016-01-01 00:14:27
# 4      4         1  2016-01-01 00:00:06   2016-01-01 00:04:44
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1            1.2        -73.979424        40.744614
# 1                1            6.0        -73.947151        40.791046
# 2                1            3.7        -74.004303        40.742241
# 3                2            2.2        -73.991997        40.718578
# 4                1            1.7        -73.982101        40.774696
#
#    RatecodeID store_and_fwd_flag      ...       fare_amount  extra  mta_tax  \
# 0           1                  N      ...               9.0    0.5      0.5
# 1           1                  N      ...              18.0    0.5      0.5
# 2           1                  N      ...              14.0    0.5      0.5
# 3           1                  N      ...              11.0    0.5      0.5
# 4           1                  Y      ...               7.0    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  travel_date  \
# 0        0.00           0.0                    0.3         10.30   2016-01-01
# 1        0.00           0.0                    0.3         19.30   2016-01-01
# 2        3.05           0.0                    0.3         18.35   2016-01-01
# 3        1.50           0.0                    0.3         13.80   2016-01-01
# 4        1.65           0.0                    0.3          9.95   2016-01-01
#
#    pickup_area  dropoff_area
# 0    Manhattan     Manhattan
# 1    Manhattan     Manhattan
# 2    Manhattan     Manhattan
# 3    Manhattan     Manhattan
# 4    Manhattan     Manhattan
#
# [5 rows x 23 columns]

# %%
df = df[df['pickup_area'] != 'Not Specified']
df = df[df['dropoff_area'] != 'Not Specified']
df
# Out:
#      index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0        0         1  2016-01-01 00:00:01   2016-01-01 00:11:55
# 1        1         1  2016-01-01 00:00:02   2016-01-01 00:11:14
# 2        2         1  2016-01-01 00:00:04   2016-01-01 00:14:32
# 3        3         1  2016-01-01 00:00:05   2016-01-01 00:14:27
# 4        4         1  2016-01-01 00:00:06   2016-01-01 00:04:44
# 5        5         1  2016-01-01 00:00:07   2016-01-01 00:20:35
# 6        6         1  2016-01-01 00:00:07   2016-01-01 00:09:49
# 7        7         1  2016-01-01 00:00:09   2016-01-01 00:19:03
# 8        8         1  2016-01-01 00:00:09   2016-01-01 00:07:18
# 9        9         1  2016-01-01 00:00:14   2016-01-01 00:13:02
# 10      10         1  2016-01-01 00:00:16   2016-01-01 00:33:00
# 11      11         1  2016-01-01 00:00:17   2016-01-01 00:19:14
# 12      12         1  2016-01-01 00:00:17   2016-01-01 00:13:59
# 14      14         1  2016-01-01 00:00:20   2016-01-01 00:29:05
# 15      15         1  2016-01-01 00:00:21   2016-01-01 00:17:30
# 16      16         1  2016-01-01 00:00:21   2016-01-01 00:32:09
# 17      17         1  2016-01-01 00:00:26   2016-01-01 00:07:41
# 18      18         1  2016-01-01 00:00:27   2016-01-01 00:17:41
# 19      19         1  2016-01-01 00:00:28   2016-01-01 00:22:51
# 20      20         1  2016-01-01 00:00:30   2016-01-01 00:15:47
# 21      21         1  2016-01-01 00:00:31   2016-01-01 00:03:57
# 22      22         1  2016-01-01 00:00:34   2016-01-01 00:10:36
# 23      23         1  2016-01-01 00:00:37   2016-01-01 00:06:01
# 24      24         1  2016-01-01 00:00:38   2016-01-01 00:17:25
# 25      25         1  2016-01-01 00:00:39   2016-01-01 00:08:41
# 26      26         1  2016-01-01 00:00:40   2016-01-01 00:14:03
# 27      27         1  2016-01-01 00:00:40   2016-01-01 00:11:05
# 28      28         1  2016-01-01 00:00:48   2016-01-01 00:03:38
# 29      29         1  2016-01-01 00:00:49   2016-01-01 00:13:15
# 30      30         1  2016-01-01 00:00:52   2016-01-01 00:29:50
# ..     ...       ...                  ...                   ...
# 470  49970         1  2016-01-01 04:24:19   2016-01-01 04:29:00
# 471  49971         1  2016-01-01 04:24:19   2016-01-01 04:26:55
# 472  49972         1  2016-01-01 04:24:20   2016-01-01 04:26:16
# 473  49973         1  2016-01-01 04:24:20   2016-01-01 04:31:16
# 474  49974         1  2016-01-01 04:24:21   2016-01-01 04:42:06
# 475  49975         1  2016-01-01 04:24:21   2016-01-01 04:36:29
# 476  49976         1  2016-01-01 04:24:21   2016-01-01 04:36:42
# 477  49977         1  2016-01-01 04:24:22   2016-01-01 04:27:17
# 478  49978         1  2016-01-01 04:24:22   2016-01-01 04:34:39
# 479  49979         1  2016-01-01 04:24:23   2016-01-01 04:36:39
# 480  49980         1  2016-01-01 04:24:23   2016-01-01 04:42:29
# 481  49981         1  2016-01-01 04:24:23   2016-01-01 04:31:23
# 482  49982         1  2016-01-01 04:24:23   2016-01-01 04:49:07
# 483  49983         1  2016-01-01 04:24:24   2016-01-01 04:40:20
# 484  49984         1  2016-01-01 04:24:24   2016-01-01 04:27:28
# 485  49985         1  2016-01-01 04:24:24   2016-01-01 04:27:37
# 486  49986         1  2016-01-01 04:24:24   2016-01-01 04:44:43
# 487  49987         1  2016-01-01 04:24:24   2016-01-01 04:45:49
# 488  49988         1  2016-01-01 04:24:25   2016-01-01 04:40:27
# 489  49989         1  2016-01-01 04:24:25   2016-01-01 04:34:19
# 490  49990         1  2016-01-01 04:24:25   2016-01-01 04:26:49
# 491  49991         1  2016-01-01 04:24:26   2016-01-01 04:35:58
# 492  49992         1  2016-01-01 04:24:26   2016-01-01 04:56:06
# 493  49993         1  2016-01-01 04:24:26   2016-01-01 04:29:08
# 494  49994         1  2016-01-01 04:24:27   2016-01-01 04:45:57
# 495  49995         1  2016-01-01 04:24:27   2016-01-01 04:44:01
# 496  49996         1  2016-01-01 04:24:27   2016-01-01 04:29:54
# 497  49997         1  2016-01-01 04:24:28   2016-01-01 04:34:00
# 498  49998         1  2016-01-01 04:24:29   2016-01-01 04:33:58
# 499  49999         1  2016-01-01 04:24:29   2016-01-01 04:34:12
#
#      passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                  1            1.2        -73.979424        40.744614
# 1                  1            6.0        -73.947151        40.791046
# 2                  1            3.7        -74.004303        40.742241
# 3                  2            2.2        -73.991997        40.718578
# 4                  1            1.7        -73.982101        40.774696
# 5                  2            4.9        -73.953033        40.672115
# 6                  1            1.8        -73.989166        40.726589
# 7                  3            5.3        -73.997131        40.736961
# 8                  2            1.2        -73.963913        40.712173
# 9                  1            2.4        -73.995598        40.744240
# 10                 2            2.9        -73.982155        40.774879
# 11                 1            1.2        -74.008064        40.742069
# 12                 1            1.5        -74.002678        40.730637
# 14                 1           13.0        -73.982239        40.757702
# 15                 1            0.7        -73.894127        40.636574
# 16                 1            5.4        -73.946419        40.789139
# 17                 1            1.3        -73.965881        40.688564
# 18                 1            4.7        -73.995865        40.767773
# 19                 1           15.4        -73.976501        40.733562
# 20                 1            5.1        -73.990585        40.745880
# 21                 1            1.3        -73.933525        40.802929
# 22                 1            3.7        -73.978317        40.763180
# 23                 1            1.2        -73.976021        40.744560
# 24                 1            8.8        -73.976791        40.733700
# 25                 1            2.2        -73.969872        40.768509
# 26                 1            4.3        -73.966179        40.762222
# 27                 2            1.3        -74.004379        40.742252
# 28                 1            0.8        -73.979156        40.740509
# 29                 2            8.7        -73.953926        40.766945
# 30                 2            3.1        -73.984047        40.755280
# ..               ...            ...               ...              ...
# 470                1            1.2        -73.827858        40.754169
# 471                1            0.6        -73.992607        40.723728
# 472                2            0.5        -73.990173        40.748981
# 473                1            1.6        -73.972626        40.756153
# 474                1            7.9        -74.004219        40.752773
# 475                1            4.9        -73.938644        40.805851
# 476                1            3.2        -73.984650        40.686890
# 477                1            0.4        -74.006195        40.733673
# 478                1            3.9        -73.985466        40.727673
# 479                2            6.1        -74.013199        40.709259
# 480                1            5.1        -73.986549        40.733086
# 481                1            1.1        -73.977112        40.787868
# 482                1            5.0        -73.974785        40.736652
# 483                1            7.3        -73.983688        40.749805
# 484                1            0.8        -73.942085        40.797832
# 485                2            0.5        -73.990334        40.756519
# 486                2            5.0        -73.999969        40.728573
# 487                1           12.0        -73.994225        40.751228
# 488                1            4.2        -73.995827        40.722775
# 489                1            1.6        -74.000435        40.735558
# 490                1            0.6        -73.978149        40.745735
# 491                1            3.7        -73.985130        40.721966
# 492                2            7.2        -73.966110        40.753914
# 493                1            0.5        -73.985664        40.726864
# 494                1            3.6        -73.961937        40.715790
# 495                1            5.1        -73.989883        40.735390
# 496                3            1.6        -73.972000        40.764591
# 497                1            1.2        -73.958565        40.717236
# 498                1            1.3        -73.946556        40.806435
# 499                1            2.8        -73.977898        40.763287
#
#      RatecodeID store_and_fwd_flag      ...       fare_amount  extra  mta_tax  \
# 0             1                  N      ...               9.0    0.5      0.5
# 1             1                  N      ...              18.0    0.5      0.5
# 2             1                  N      ...              14.0    0.5      0.5
# 3             1                  N      ...              11.0    0.5      0.5
# 4             1                  Y      ...               7.0    0.5      0.5
# 5             1                  N      ...              19.0    0.5      0.5
# 6             1                  N      ...               9.0    0.5      0.5
# 7             1                  N      ...              18.0    0.5      0.5
# 8             1                  N      ...               7.0    0.5      0.5
# 9             1                  N      ...              11.0    0.5      0.5
# 10            1                  N      ...              20.5    0.5      0.5
# 11            1                  N      ...              12.5    0.5      0.5
# 12            1                  N      ...              10.0    0.5      0.5
# 14            1                  N      ...              36.5    0.5      0.5
# 15            1                  Y      ...              11.0    0.5      0.5
# 16            1                  N      ...              24.5    0.5      0.5
# 17            1                  N      ...               7.5    0.5      0.5
# 18            1                  N      ...              17.0    0.5      0.5
# 19            1                  N      ...              41.5    0.5      0.5
# 20            1                  N      ...              17.5    0.5      0.5
# 21            1                  N      ...               5.5    0.5      0.5
# 22            1                  N      ...              13.0    0.5      0.5
# 23            1                  N      ...               6.5    0.5      0.5
# 24            1                  N      ...              26.0    0.5      0.5
# 25            1                  N      ...               9.0    0.5      0.5
# 26            1                  N      ...              15.5    0.5      0.5
# 27            1                  N      ...               8.5    0.5      0.5
# 28            1                  N      ...               4.5    0.5      0.5
# 29            1                  N      ...              25.0    0.5      0.5
# 30            1                  N      ...              19.5    0.5      0.5
# ..          ...                ...      ...               ...    ...      ...
# 470           1                  N      ...               6.0    0.5      0.5
# 471           1                  N      ...               4.5    0.5      0.5
# 472           1                  N      ...               4.0    0.5      0.5
# 473           1                  Y      ...               7.5    0.5      0.5
# 474           1                  N      ...              24.0    0.5      0.5
# 475           1                  N      ...              16.5    0.5      0.5
# 476           1                  N      ...              13.0    0.5      0.5
# 477           1                  N      ...               4.0    0.5      0.5
# 478           1                  N      ...              13.0    0.5      0.5
# 479           1                  N      ...              18.5    0.5      0.5
# 480           1                  N      ...              18.0    0.5      0.5
# 481           1                  N      ...               7.0    0.5      0.5
# 482           1                  N      ...              16.5    0.5      0.5
# 483           1                  N      ...              22.0    0.5      0.5
# 484           1                  N      ...               4.5    0.5      0.5
# 485           1                  N      ...               4.5    0.5      0.5
# 486           1                  N      ...              19.0    0.5      0.5
# 487           1                  N      ...              34.0    0.5      0.5
# 488           1                  N      ...              16.0    0.5      0.5
# 489           1                  N      ...               8.5    0.5      0.5
# 490           1                  N      ...               4.0    0.5      0.5
# 491           1                  N      ...              12.5    0.5      0.5
# 492           1                  N      ...              28.0    0.5      0.5
# 493           1                  N      ...               5.0    0.5      0.5
# 494           1                  N      ...              17.0    0.5      0.5
# 495           1                  N      ...              18.5    0.5      0.5
# 496           1                  N      ...               7.0    0.5      0.5
# 497           1                  N      ...               7.5    0.5      0.5
# 498           1                  N      ...               8.0    0.5      0.5
# 499           1                  N      ...              11.0    0.5      0.5
#
#      tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0          0.00          0.00                    0.3         10.30
# 1          0.00          0.00                    0.3         19.30
# 2          3.05          0.00                    0.3         18.35
# 3          1.50          0.00                    0.3         13.80
# 4          1.65          0.00                    0.3          9.95
# 5          4.06          0.00                    0.3         24.36
# 6          0.00          0.00                    0.3         10.30
# 7          3.85          0.00                    0.3         23.15
# 8          0.00          0.00                    0.3          8.30
# 9          3.05          0.00                    0.3         15.35
# 10         0.00          0.00                    0.3         21.80
# 11         0.00          0.00                    0.3         13.80
# 12         3.35          0.00                    0.3         14.65
# 14         0.00          0.00                    0.3         37.80
# 15         0.00          0.00                    0.3         12.30
# 16         0.00          0.00                    0.3         25.80
# 17         1.75          0.00                    0.3         10.55
# 18         2.00          0.00                    0.3         20.30
# 19         8.55          0.00                    0.3         51.35
# 20         2.82          0.00                    0.3         21.62
# 21         0.00          0.00                    0.3          6.80
# 22         5.70          0.00                    0.3         20.00
# 23         2.30          0.00                    0.3         10.10
# 24         5.45          0.00                    0.3         32.75
# 25         0.00          0.00                    0.3         10.30
# 26         0.00          0.00                    0.3         16.80
# 27         1.00          0.00                    0.3         10.80
# 28         1.45          0.00                    0.3          7.25
# 29         0.00          0.00                    0.3         26.30
# 30         4.15          0.00                    0.3         24.95
# ..          ...           ...                    ...           ...
# 470        0.00          0.00                    0.3          7.30
# 471        1.00          0.00                    0.3          6.80
# 472        0.00          0.00                    0.3          5.30
# 473        1.75          0.00                    0.3         10.55
# 474        0.00          0.00                    0.3         25.30
# 475        0.00          0.00                    0.3         17.80
# 476        0.00          0.00                    0.3         14.30
# 477        0.00          0.00                    0.3          5.30
# 478        2.00          0.00                    0.3         16.30
# 479        5.90          0.00                    0.3         25.70
# 480        3.85          0.00                    0.3         23.15
# 481        0.00          0.00                    0.3          8.30
# 482        0.00          0.00                    0.3         17.80
# 483        4.65          0.00                    0.3         27.95
# 484        0.00          0.00                    0.3          5.80
# 485        1.45          0.00                    0.3          7.25
# 486        4.06          0.00                    0.3         24.36
# 487        8.15          5.54                    0.3         48.99
# 488        0.00          0.00                    0.3         17.30
# 489        0.00          0.00                    0.3          9.80
# 490        0.00          0.00                    0.3          5.30
# 491        2.75          0.00                    0.3         16.55
# 492        0.00          0.00                    0.3         29.30
# 493        1.25          0.00                    0.3          7.55
# 494        3.65          0.00                    0.3         21.95
# 495        5.90          0.00                    0.3         25.70
# 496        0.00          0.00                    0.3          8.30
# 497        0.00          0.00                    0.3          8.80
# 498        0.00          0.00                    0.3          9.30
# 499        2.45          0.00                    0.3         14.75
#
#      travel_date  pickup_area  dropoff_area
# 0     2016-01-01    Manhattan     Manhattan
# 1     2016-01-01    Manhattan     Manhattan
# 2     2016-01-01    Manhattan     Manhattan
# 3     2016-01-01    Manhattan     Manhattan
# 4     2016-01-01    Manhattan     Manhattan
# 5     2016-01-01     Brooklyn     Manhattan
# 6     2016-01-01    Manhattan     Manhattan
# 7     2016-01-01    Manhattan        Queens
# 8     2016-01-01     Brooklyn      Brooklyn
# 9     2016-01-01    Manhattan     Manhattan
# 10    2016-01-01    Manhattan     Manhattan
# 11    2016-01-01    Manhattan     Manhattan
# 12    2016-01-01    Manhattan     Manhattan
# 14    2016-01-01    Manhattan         Bronx
# 15    2016-01-01     Brooklyn      Brooklyn
# 16    2016-01-01    Manhattan         Bronx
# 17    2016-01-01     Brooklyn      Brooklyn
# 18    2016-01-01    Manhattan     Manhattan
# 19    2016-01-01    Manhattan         Bronx
# 20    2016-01-01    Manhattan     Manhattan
# 21    2016-01-01    Manhattan     Manhattan
# 22    2016-01-01    Manhattan        Queens
# 23    2016-01-01    Manhattan     Manhattan
# 24    2016-01-01    Manhattan        Queens
# 25    2016-01-01    Manhattan     Manhattan
# 26    2016-01-01    Manhattan        Queens
# 27    2016-01-01    Manhattan     Manhattan
# 28    2016-01-01    Manhattan     Manhattan
# 29    2016-01-01    Manhattan     Manhattan
# 30    2016-01-01    Manhattan     Manhattan
# ..           ...          ...           ...
# 470   2016-01-01       Queens        Queens
# 471   2016-01-01    Manhattan     Manhattan
# 472   2016-01-01    Manhattan     Manhattan
# 473   2016-01-01    Manhattan     Manhattan
# 474   2016-01-01    Manhattan     Manhattan
# 475   2016-01-01    Manhattan         Bronx
# 476   2016-01-01     Brooklyn     Manhattan
# 477   2016-01-01    Manhattan     Manhattan
# 478   2016-01-01    Manhattan     Manhattan
# 479   2016-01-01    Manhattan     Manhattan
# 480   2016-01-01    Manhattan     Manhattan
# 481   2016-01-01    Manhattan     Manhattan
# 482   2016-01-01    Manhattan        Queens
# 483   2016-01-01    Manhattan     Manhattan
# 484   2016-01-01    Manhattan     Manhattan
# 485   2016-01-01    Manhattan     Manhattan
# 486   2016-01-01    Manhattan      Brooklyn
# 487   2016-01-01    Manhattan        Queens
# 488   2016-01-01    Manhattan      Brooklyn
# 489   2016-01-01    Manhattan     Manhattan
# 490   2016-01-01    Manhattan     Manhattan
# 491   2016-01-01    Manhattan     Manhattan
# 492   2016-01-01    Manhattan        Queens
# 493   2016-01-01    Manhattan     Manhattan
# 494   2016-01-01     Brooklyn     Manhattan
# 495   2016-01-01    Manhattan      Brooklyn
# 496   2016-01-01    Manhattan     Manhattan
# 497   2016-01-01     Brooklyn      Brooklyn
# 498   2016-01-01    Manhattan     Manhattan
# 499   2016-01-01    Manhattan     Manhattan
#
# [146038 rows x 23 columns]

# %%
group_by_series = df['total_amount'].groupby([df['pickup_area'], df['payment_type']]).mean()
group_by_df = group_by_series.to_frame()
group_by_df = group_by_df.reset_index()
#Filter Cash and Credit payments
group_by_df = group_by_df[group_by_df['payment_type'].isin([1,2])]
group_by_df['payment_type'] = group_by_df['payment_type'].apply(lambda x: 'Credit' if x == 1 else 'Cash')
group_by_df = group_by_df.rename(columns = {'pickup_area':'Pick-Up Area', 'payment_type':'Payment Type', 'total_amount':'Average'})

# %%
group_by_df
# Out:
#      Pick-Up Area Payment Type    Average
# 0           Bronx       Credit  23.690989
# 1           Bronx         Cash  14.195764
# 4        Brooklyn       Credit  20.202585
# 5        Brooklyn         Cash  14.222778
# 8       Manhattan       Credit  15.167092
# 9       Manhattan         Cash  12.160905
# 12         Queens       Credit  40.453579
# 13         Queens         Cash  25.320589
# 16  Staten Island       Credit  46.800000
# 17  Staten Island         Cash  11.800000

# %%
myColors = ["#FF8C00","#DC143C"]
rc={'axes.labelsize': 24, 'legend.fontsize': 24.0}
sns.set(rc=rc, style='whitegrid')
factor_plot = sns.factorplot(x="Pick-Up Area", y="Average", hue="Payment Type",
                             data=group_by_df, kind = 'bar' , size = 16, palette=myColors,
                             legend=True, legend_out=False)
factor_plot.despine(left=True)

#Title
figure_title = factor_plot.fig.suptitle('Average Credit Vs. Cash Per Borough')
figure_title.set_position([.5, 1.02])
figure_title.set_color(color='#4D4D4D')
figure_title.set_fontweight(weight='bold')
figure_title.set_fontsize(36)

#XYLabels
factor_plot.ax.xaxis.set_label_text('Borough', weight='bold')
factor_plot.ax.xaxis.get_label().set_fontsize(30)
factor_plot.ax.xaxis.get_label().set_color('#4D4D4D')

factor_plot.ax.yaxis.set_label_text('Total Amount', weight='bold')
factor_plot.ax.yaxis.get_label().set_fontsize(30)
factor_plot.ax.yaxis.get_label().set_color('#4D4D4D')

#XTick
factor_plot.set_xticklabels(rotation=45, fontsize=24, color='#B2912F',fontweight='bold')
factor_plot.set_yticklabels(fontsize=24, color='#B2912F',fontweight='bold')

#Annotations
font ={'family': 'serif','weight': 'bold','size': 20, 'color':'#5DA5DA'}
for p in factor_plot.ax.patches:
    percentage = p.get_height()
    factor_plot.ax.text(p.get_x(), percentage+0.5, '%1.2f'%(percentage), fontdict= font)
